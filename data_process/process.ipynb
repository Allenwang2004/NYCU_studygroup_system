# %% [markdown]
# ### Transform the data to df

# %%
import pandas as pd
import os

# %%
symbols = {'BTCUSDT','ETHUSDT','BNBUSDT'}

# %%
data_dict = {
    'close': pd.DataFrame(),
    'high': pd.DataFrame(),
    'low': pd.DataFrame(),
    'open': pd.DataFrame(),
    'volume': pd.DataFrame()
}

for symbol in symbols:
    file_path = f'D:/NYCU_studygroup_system/data/pricevolumn/{symbol}.csv'
    data = pd.read_csv(file_path)
    
    close_df = data[['timestamp', 'close']]
    close_df.set_index('timestamp', inplace=True)
    close_df.columns = [symbol]
    if data_dict['close'].empty:
        data_dict['close'] = close_df
    else:
        data_dict['close'] = pd.concat([data_dict['close'], close_df], axis=1)
    
    high_df = data[['timestamp', 'high']]
    high_df.set_index('timestamp', inplace=True)
    high_df.columns = [symbol]
    if data_dict['high'].empty:
        data_dict['high'] = high_df
    else:
        data_dict['high'] = pd.concat([data_dict['high'], high_df], axis=1)

    low_df = data[['timestamp', 'low']]
    low_df.set_index('timestamp', inplace=True)
    low_df.columns = [symbol]
    if data_dict['low'].empty:
        data_dict['low'] = low_df
    else:
        data_dict['low'] = pd.concat([data_dict['low'], low_df], axis=1)

    open_df = data[['timestamp', 'open']]
    open_df.set_index('timestamp', inplace=True)
    open_df.columns = [symbol]
    if data_dict['open'].empty:
        data_dict['open'] = open_df
    else:
        data_dict['open'] = pd.concat([data_dict['open'], open_df], axis=1)

    volume_df = data[['timestamp', 'volume']]
    volume_df.set_index('timestamp', inplace=True)
    volume_df.columns = [symbol]
    if data_dict['volume'].empty:
        data_dict['volume'] = volume_df
    else:
        data_dict['volume'] = pd.concat([data_dict['volume'], volume_df], axis=1)

print(data_dict)
# Out:
# {'close':             BNBUSDT  BTCUSDT  ETHUSDT
# timestamp
# 2024-01-01   313.53  44230.2  2354.62
# 2024-01-02   311.88  44979.8  2356.93
# 2024-01-03   315.60  42849.5  2210.39
# 2024-01-04   323.02  44143.8  2267.85
# 2024-01-05   317.14  44145.4  2268.93
# ...             ...      ...      ...
# 2024-07-27   581.91  67873.8  3248.17
# 2024-07-28   584.21  68215.5  3268.03
# 2024-07-29   574.46  66750.0  3316.87
# 2024-07-30   588.34  66159.3  3278.17
# 2024-07-31   576.79  64601.8  3231.48
#
# [213 rows x 3 columns], 'high':             BNBUSDT  BTCUSDT  ETHUSDT
# timestamp
# 2024-01-01   315.37  44266.0  2354.95
# 2024-01-02   321.14  45950.0  2434.49
# 2024-01-03   334.30  45582.3  2387.48
# 2024-01-04   324.15  44840.8  2295.55
# 2024-01-05   326.60  44500.0  2278.16
# ...             ...      ...      ...
# 2024-07-27   593.02  69381.7  3326.90
# 2024-07-28   585.34  68300.0  3284.57
# 2024-07-29   597.64  70081.0  3396.07
# 2024-07-30   588.52  66966.6  3365.00
# 2024-07-31   593.34  66826.3  3348.74
#
# [213 rows x 3 columns], 'low':             BNBUSDT  BTCUSDT  ETHUSDT
# timestamp
# 2024-01-01   306.65  42207.9  2266.67
# 2024-01-02   304.90  44200.9  2335.00
# 2024-01-03   285.38  40333.0  2067.16
# 2024-01-04   310.58  42625.0  2202.10
# 2024-01-05   308.00  42300.0  2206.00
# ...             ...      ...      ...
# 2024-07-27   573.04  66624.5  3188.89
# 2024-07-28   574.79  67037.0  3195.84
# 2024-07-29   572.62  66365.8  3256.56
# 2024-07-30   566.83  65254.5  3230.10
# 2024-07-31   575.17  64500.4  3212.32
#
# [213 rows x 3 columns], 'open':             BNBUSDT  BTCUSDT  ETHUSDT
# timestamp
# 2024-01-01   311.33  42314.0  2283.84
# 2024-01-02   313.53  44230.3  2354.63
# 2024-01-03   311.88  44979.7  2356.92
# 2024-01-04   315.60  42849.5  2210.39
# 2024-01-05   323.02  44143.8  2267.85
# ...             ...      ...      ...
# 2024-07-27   581.04  67882.5  3272.81
# 2024-07-28   581.92  67873.7  3248.16
# 2024-07-29   584.21  68215.5  3268.03
# 2024-07-30   574.46  66750.1  3316.86
# 2024-07-31   588.32  66159.3  3278.17
#
# [213 rows x 3 columns], 'volume':                BNBUSDT     BTCUSDT      ETHUSDT
# timestamp
# 2024-01-01   893204.63  206424.144  1658563.418
# 2024-01-02  1412989.05  459798.523  3376173.730
# 2024-01-03  4187171.99  595855.225  4996919.678
# 2024-01-04  1605932.56  333923.098  2512800.256
# 2024-01-05  1720089.71  374967.791  2640741.967
# ...                ...         ...          ...
# 2024-07-27   490613.36  330982.647  2181510.660
# 2024-07-28   237478.19  116913.935  1114442.469
# 2024-07-29   536206.75  372537.818  2897273.325
# 2024-07-30   403873.86  246551.044  2000830.475
# 2024-07-31   547231.94  246389.446  2173585.083
#
# [213 rows x 3 columns]}
