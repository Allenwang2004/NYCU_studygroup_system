# %%
import sys
import os
import requests
import pandas as pd
from datetime import datetime, timedelta
from pathlib import Path
import mplfinance as mpf
import matplotlib.pyplot as plt
import numpy as np

# %%
def getopen(symbol, start_time, end_time, interval, limit, path):
    
    base_url = 'https://fapi.binance.com'
    symbol = symbol
    limit = limit
    interval = interval
    def timestamp_to_int(dt):
        return int(datetime.timestamp(dt) * 1000)

    start_time = timestamp_to_int(start_time)
    end_time = timestamp_to_int(end_time)

    def get_historical_klines(df, start_time):
        endpoint = '/fapi/v1/klines'
        Interval = interval
        params = {
            'symbol': symbol,
            'interval': Interval,
            'startTime': start_time,
            'endTime': start_time + limit * 60 * 1000 - 1,
            'limit': 1000
        }
        url = base_url + endpoint
        response = requests.get(url, params=params)

        if response.status_code == 200:
            data = response.json()
            klines_df = pd.DataFrame(data, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'])
            klines_df['timestamp'] = pd.to_datetime(klines_df['timestamp'], unit='ms')
            df = pd.concat([df, klines_df], ignore_index=True)
            print(f'Symbol: {symbol}, Fetched {len(klines_df)} klines from {klines_df["timestamp"].min()} to {klines_df["timestamp"].max()}')
        else:
            print(f'Error: {response.status_code}')

        return df
    
    df = pd.DataFrame()

    # Fetch data in loop
    while start_time < end_time:
        df = get_historical_klines(df, start_time)
        start_time += limit * 60 * 1000

    print(df)
    filepath = Path(path)
    filepath.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(filepath)

def gethigh(symbol, start_time, end_time, interval, limit, path):
    
    base_url = 'https://fapi.binance.com'
    symbol = symbol
    limit = limit
    interval = interval
    def timestamp_to_int(dt):
        return int(datetime.timestamp(dt) * 1000)

    start_time = timestamp_to_int(start_time)
    end_time = timestamp_to_int(end_time)

    def get_historical_klines(df, start_time):
        endpoint = '/fapi/v1/klines'
        Interval = interval
        params = {
            'symbol': symbol,
            'interval': Interval,
            'startTime': start_time,
            'endTime': start_time + limit * 60 * 1000 - 1,
            'limit': 1000
        }
        url = base_url + endpoint
        response = requests.get(url, params=params)

        if response.status_code == 200:
            data = response.json()
            klines_df = pd.DataFrame(data, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'])
            klines_df['timestamp'] = pd.to_datetime(klines_df['timestamp'], unit='ms')
            df = pd.concat([df, klines_df], ignore_index=True)
            print(f'Symbol: {symbol}, Fetched {len(klines_df)} klines from {klines_df["timestamp"].min()} to {klines_df["timestamp"].max()}')
        else:
            print(f'Error: {response.status_code}')

        return df
    
    df = pd.DataFrame()

    # Fetch data in loop
    while start_time < end_time:
        df = get_historical_klines(df, start_time)
        start_time += limit * 60 * 1000

    print(df)
    filepath = Path(path)
    filepath.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(filepath)

def getlow(symbol, start_time, end_time, interval, limit, path):
    
    base_url = 'https://fapi.binance.com'
    symbol = symbol
    limit = limit
    interval = interval
    def timestamp_to_int(dt):
        return int(datetime.timestamp(dt) * 1000)

    start_time = timestamp_to_int(start_time)
    end_time = timestamp_to_int(end_time)

    def get_historical_klines(df, start_time):
        endpoint = '/fapi/v1/klines'
        Interval = interval
        params = {
            'symbol': symbol,
            'interval': Interval,
            'startTime': start_time,
            'endTime': start_time + limit * 60 * 1000 - 1,
            'limit': 1000
        }
        url = base_url + endpoint
        response = requests.get(url, params=params)

        if response.status_code == 200:
            data = response.json()
            klines_df = pd.DataFrame(data, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'])
            klines_df['timestamp'] = pd.to_datetime(klines_df['timestamp'], unit='ms')
            df = pd.concat([df, klines_df], ignore_index=True)
            print(f'Symbol: {symbol}, Fetched {len(klines_df)} klines from {klines_df["timestamp"].min()} to {klines_df["timestamp"].max()}')
        else:
            print(f'Error: {response.status_code}')

        return df
    
    df = pd.DataFrame()

    # Fetch data in loop
    while start_time < end_time:
        df = get_historical_klines(df, start_time)
        start_time += limit * 60 * 1000

    print(df)
    filepath = Path(path)
    filepath.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(filepath)

def getclose(symbol, start_time, end_time, interval, limit, path):
    
    base_url = 'https://fapi.binance.com'
    symbol = symbol
    limit = limit
    interval = interval
    def timestamp_to_int(dt):
        return int(datetime.timestamp(dt) * 1000)

    start_time = timestamp_to_int(start_time)
    end_time = timestamp_to_int(end_time)

    def get_historical_klines(df, start_time):
        endpoint = '/fapi/v1/klines'
        Interval = interval
        params = {
            'symbol': symbol,
            'interval': Interval,
            'startTime': start_time,
            'endTime': start_time + limit * 60 * 1000 - 1,
            'limit': 1000
        }
        url = base_url + endpoint
        response = requests.get(url, params=params)

        if response.status_code == 200:
            data = response.json()
            klines_df = pd.DataFrame(data, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'])
            klines_df['timestamp'] = pd.to_datetime(klines_df['timestamp'], unit='ms')
            df = pd.concat([df, klines_df], ignore_index=True)
            print(f'Symbol: {symbol}, Fetched {len(klines_df)} klines from {klines_df["timestamp"].min()} to {klines_df["timestamp"].max()}')
        else:
            print(f'Error: {response.status_code}')

        return df
    
    df = pd.DataFrame()

    # Fetch data in loop
    while start_time < end_time:
        df = get_historical_klines(df, start_time)
        start_time += limit * 60 * 1000

    print(df)
    filepath = Path(path)
    filepath.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(filepath)

def getvolumn(symbol, start_time, end_time, interval, limit, path):
    
    base_url = 'https://fapi.binance.com'
    symbol = symbol
    limit = limit
    interval = interval
    def timestamp_to_int(dt):
        return int(datetime.timestamp(dt) * 1000)

    start_time = timestamp_to_int(start_time)
    end_time = timestamp_to_int(end_time)

    def get_historical_klines(df, start_time):
        endpoint = '/fapi/v1/klines'
        Interval = interval
        params = {
            'symbol': symbol,
            'interval': Interval,
            'startTime': start_time,
            'endTime': start_time + limit * 60 * 1000 - 1,
            'limit': 1000
        }
        url = base_url + endpoint
        response = requests.get(url, params=params)

        if response.status_code == 200:
            data = response.json()
            klines_df = pd.DataFrame(data, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'])
            klines_df['timestamp'] = pd.to_datetime(klines_df['timestamp'], unit='ms')
            df = pd.concat([df, klines_df], ignore_index=True)
            print(f'Symbol: {symbol}, Fetched {len(klines_df)} klines from {klines_df["timestamp"].min()} to {klines_df["timestamp"].max()}')
        else:
            print(f'Error: {response.status_code}')

        return df
    
    df = pd.DataFrame()

    # Fetch data in loop
    while start_time < end_time:
        df = get_historical_klines(df, start_time)
        start_time += limit * 60 * 1000

    print(df)
    filepath = Path(path)
    filepath.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(filepath)

# %% [markdown]
# ### 解決起始時間的問題

# %%
#symbol_pool = {'BTCUSDT','ETHUSDT','BNBUSDT','SOLUSDT','XRPUSDT','DOGEUSDT','ADAUSDT','TRXUSDT','WBTCUSDT','AVAXUSDT','SHIBUSDT','DOTUSDT','BCHUSDT','LINKUSDT','DAUUSDT','LTCUSDT','MATICUSDT','NEARUSDT','ICPUSDT','UNIUSDT','PEPEUSDT','ETCUSDT','XLMUSDT','APTUSDT','WBETHUSDT','FETUSDT','HBARUSDT','FILUSDT'}

# %%
symbol_pool = {'BTCUSDT','ETHUSDT','BNBUSDT'}

# %%
for symbol in symbol_pool:
    #存成'symbol'open1d.csv
    print(symbol)
    getopen(symbol,datetime(2024, 1, 1),datetime(2024, 8, 1),'1d',1440,'C:/Quant/Studygroup_system/data/open/'+symbol+'open1d.csv')
# Out:
# BTCUSDT
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-01 00:00:00 to 2024-01-01 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-02 00:00:00 to 2024-01-02 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-03 00:00:00 to 2024-01-03 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-04 00:00:00 to 2024-01-04 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-05 00:00:00 to 2024-01-05 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-06 00:00:00 to 2024-01-06 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-07 00:00:00 to 2024-01-07 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-08 00:00:00 to 2024-01-08 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-09 00:00:00 to 2024-01-09 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-10 00:00:00 to 2024-01-10 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-11 00:00:00 to 2024-01-11 00:00:00
# ...

# %%
for symbol in symbol_pool:
    #存成'symbol'close1d.csv
    print(symbol)
    getopen(symbol,datetime(2024, 1, 1),datetime(2024, 8, 1),'1d',1440,'C:/Quant/Studygroup_system/data/close/'+symbol+'close1d.csv')
# Out:
# BTCUSDT
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-01 00:00:00 to 2024-01-01 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-02 00:00:00 to 2024-01-02 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-03 00:00:00 to 2024-01-03 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-04 00:00:00 to 2024-01-04 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-05 00:00:00 to 2024-01-05 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-06 00:00:00 to 2024-01-06 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-07 00:00:00 to 2024-01-07 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-08 00:00:00 to 2024-01-08 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-09 00:00:00 to 2024-01-09 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-10 00:00:00 to 2024-01-10 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-11 00:00:00 to 2024-01-11 00:00:00
# ...

# %%
for symbol in symbol_pool:
    #存成'symbol'high1d.csv
    print(symbol)
    getopen(symbol,datetime(2024, 1, 1),datetime(2024, 8, 1),'1d',1440,'C:/Quant/Studygroup_system/data/high/'+symbol+'high1d.csv')
# Out:
# BTCUSDT
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-01 00:00:00 to 2024-01-01 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-02 00:00:00 to 2024-01-02 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-03 00:00:00 to 2024-01-03 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-04 00:00:00 to 2024-01-04 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-05 00:00:00 to 2024-01-05 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-06 00:00:00 to 2024-01-06 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-07 00:00:00 to 2024-01-07 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-08 00:00:00 to 2024-01-08 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-09 00:00:00 to 2024-01-09 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-10 00:00:00 to 2024-01-10 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-11 00:00:00 to 2024-01-11 00:00:00
# ...

# %%
for symbol in symbol_pool:
    #存成'symbol',low1d.csv
    print(symbol)
    getopen(symbol,datetime(2024, 1, 1),datetime(2024, 8, 1),'1d',1440,'C:/Quant/Studygroup_system/data/low/'+symbol+'low1d.csv')
# Out:
# BTCUSDT
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-01 00:00:00 to 2024-01-01 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-02 00:00:00 to 2024-01-02 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-03 00:00:00 to 2024-01-03 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-04 00:00:00 to 2024-01-04 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-05 00:00:00 to 2024-01-05 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-06 00:00:00 to 2024-01-06 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-07 00:00:00 to 2024-01-07 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-08 00:00:00 to 2024-01-08 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-09 00:00:00 to 2024-01-09 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-10 00:00:00 to 2024-01-10 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-11 00:00:00 to 2024-01-11 00:00:00
# ...

# %%
for symbol in symbol_pool:
    #存成'symbol'volumn1d.csv
    print(symbol)
    getopen(symbol,datetime(2024, 1, 1),datetime(2024, 8, 1),'1d',1440,'C:/Quant/Studygroup_system/data/volumn/'+symbol+'volumn1d.csv')
# Out:
# BTCUSDT
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-01 00:00:00 to 2024-01-01 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-02 00:00:00 to 2024-01-02 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-03 00:00:00 to 2024-01-03 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-04 00:00:00 to 2024-01-04 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-05 00:00:00 to 2024-01-05 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-06 00:00:00 to 2024-01-06 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-07 00:00:00 to 2024-01-07 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-08 00:00:00 to 2024-01-08 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-09 00:00:00 to 2024-01-09 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-10 00:00:00 to 2024-01-10 00:00:00
# Symbol: BTCUSDT, Fetched 1 klines from 2024-01-11 00:00:00 to 2024-01-11 00:00:00
# ...

# %%
getopen(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1m',1,'C:/Quant/Studygroup_system/data/open1m.csv')
getopen(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'3m',3,'C:/Quant/Studygroup_system/data/open3m.csv')
getopen(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'5m',5,'C:/Quant/Studygroup_system/data/open5m.csv')
getopen(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'15m',15,'C:/Quant/Studygroup_system/data/open15m.csv')
getopen(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'30m',30,'C:/Quant/Studygroup_system/data/open30m.csv')
getopen(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1h',60,'C:/Quant/Studygroup_system/data/open1h.csv')
getopen(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'2h',120,'C:/Quant/Studygroup_system/data/open2h.csv')
getopen(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'4h',240,'C:/Quant/Studygroup_system/data/open4h.csv')
getopen(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'6h',360,'C:/Quant/Studygroup_system/data/open6h.csv')
getopen(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'8h',480,'C:/Quant/Studygroup_system/data/open8h.csv')
getopen(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'12h',720,'C:/Quant/Studygroup_system/data/open12h.csv')
getopen(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1d',1440,'C:/Quant/Studygroup_system/data/open1d.csv')
getopen(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1w',10080,'C:/Quant/Studygroup_system/data/open1w.csv')
getopen(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1M',43200,'C:/Quant/Studygroup_system/data/open1M.csv')

# %%
getclose(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1m',1,'C:/Quant/Studygroup_system/data/close1m.csv')
getclose(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'3m',3,'C:/Quant/Studygroup_system/data/close3m.csv')
getclose(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'5m',5,'C:/Quant/Studygroup_system/data/close5m.csv')
getclose(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'15m',15,'C:/Quant/Studygroup_system/data/close15m.csv')
getclose(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'30m',30,'C:/Quant/Studygroup_system/data/close30m.csv')
getclose(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1h',60,'C:/Quant/Studygroup_system/data/close1h.csv')
getclose(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'2h',120,'C:/Quant/Studygroup_system/data/close2h.csv')
getclose(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'4h',240,'C:/Quant/Studygroup_system/data/close4h.csv')
getclose(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'6h',360,'C:/Quant/Studygroup_system/data/close6h.csv')
getclose(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'8h',480,'C:/Quant/Studygroup_system/data/close8h.csv')
getclose(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'12h',720,'C:/Quant/Studygroup_system/data/close12h.csv')
getclose(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1d',1440,'C:/Quant/Studygroup_system/data/close1d.csv')
getclose(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1w',10080,'C:/Quant/Studygroup_system/data/close1w.csv')
getclose(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1M',43200,'C:/Quant/Studygroup_system/data/close1M.csv')

# %%
gethigh(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1m',1,'C:/Quant/Studygroup_system/data/high1m.csv')
gethigh(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'3m',3,'C:/Quant/Studygroup_system/data/high3m.csv')
gethigh(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'5m',5,'C:/Quant/Studygroup_system/data/high5m.csv')
gethigh(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'15m',15,'C:/Quant/Studygroup_system/data/high15m.csv')
gethigh(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'30m',30,'C:/Quant/Studygroup_system/data/high30m.csv')
gethigh(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1h',60,'C:/Quant/Studygroup_system/data/high1h.csv')
gethigh(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'2h',120,'C:/Quant/Studygroup_system/data/high2h.csv')
gethigh(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'4h',240,'C:/Quant/Studygroup_system/data/high4h.csv')
gethigh(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'6h',360,'C:/Quant/Studygroup_system/data/high6h.csv')
gethigh(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'8h',480,'C:/Quant/Studygroup_system/data/high8h.csv')
gethigh(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'12h',720,'C:/Quant/Studygroup_system/data/high12h.csv')
gethigh(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1d',1440,'C:/Quant/Studygroup_system/data/high1d.csv')
gethigh(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1w',10080,'C:/Quant/Studygroup_system/data/high1w.csv')
gethigh(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1M',43200,'C:/Quant/Studygroup_system/data/high1M.csv')

# %%
getlow(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1m',1,'C:/Quant/Studygroup_system/data/low1m.csv')
getlow(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'3m',3,'C:/Quant/Studygroup_system/data/low3m.csv')
getlow(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'5m',5,'C:/Quant/Studygroup_system/data/low5m.csv')
getlow(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'15m',15,'C:/Quant/Studygroup_system/data/low15m.csv')
getlow(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'30m',30,'C:/Quant/Studygroup_system/data/low30m.csv')
getlow(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1h',60,'C:/Quant/Studygroup_system/data/low1h.csv')
getlow(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'2h',120,'C:/Quant/Studygroup_system/data/low2h.csv')
getlow(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'4h',240,'C:/Quant/Studygroup_system/data/low4h.csv')
getlow(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'6h',360,'C:/Quant/Studygroup_system/data/low6h.csv')
getlow(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'8h',480,'C:/Quant/Studygroup_system/data/low8h.csv')
getlow(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'12h',720,'C:/Quant/Studygroup_system/data/low12h.csv')
getlow(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1d',1440,'C:/Quant/Studygroup_system/data/low1d.csv')
getlow(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1w',10080,'C:/Quant/Studygroup_system/data/low1w.csv')
getlow(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1M',43200,'C:/Quant/Studygroup_system/data/low1M.csv')

# %%
getvolumn(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1m',1,'C:/Quant/Studygroup_system/data/volumn1m.csv')
getvolumn(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'3m',3,'C:/Quant/Studygroup_system/data/volumn3m.csv')
getvolumn(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'5m',5,'C:/Quant/Studygroup_system/data/volumn5m.csv')
getvolumn(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'15m',15,'C:/Quant/Studygroup_system/data/volumn15m.csv')
getvolumn(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'30m',30,'C:/Quant/Studygroup_system/data/volumn30m.csv')
getvolumn(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1h',60,'C:/Quant/Studygroup_system/data/volumn1h.csv')
getvolumn(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'2h',120,'C:/Quant/Studygroup_system/data/volumn2h.csv')
getvolumn(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'4h',240,'C:/Quant/Studygroup_system/data/volumn4h.csv')
getvolumn(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'6h',360,'C:/Quant/Studygroup_system/data/volumn6h.csv')
getvolumn(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'8h',480,'C:/Quant/Studygroup_system/data/volumn8h.csv')
getvolumn(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'12h',720,'C:/Quant/Studygroup_system/data/volumn12h.csv')
getvolumn(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1d',1440,'C:/Quant/Studygroup_system/data/volumn1d.csv')
getvolumn(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1w',10080,'C:/Quant/Studygroup_system/data/volumn1w.csv')
getvolumn(symbol_pool,datetime(2020, 7, 1),datetime(2023, 12, 31),'1M',43200,'C:/Quant/Studygroup_system/data/volumn1M.csv')
